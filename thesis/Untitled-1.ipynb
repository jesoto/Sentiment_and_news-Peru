# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
series = pd.read_excel('C:/Users/PC/Desktop/series.xlsx', sheet_name='tratada')

# %%
series.columns
# Out:
# Index(['fecha', 'date', 'var-tc', 'tc', 'index',
#        'Reservas internacionales netas',
#        'Operaciones cambiarias BCRP (millones US$)',
#        'Compras netas en Mesa de Negociación (millones US$)'],
#       dtype='object')

# %%
series.head(3)
# Out:
#      fecha       date    var-tc        tc     index  \
# 0  03Ene18 2018-01-03       NaN  3.226571  0.052818
# 1  04Ene18 2018-01-04 -0.005933  3.207429  0.001007
# 2  05Ene18 2018-01-05  0.001113  3.211000  0.045562
#
#   Reservas internacionales netas Operaciones cambiarias BCRP (millones US$)  \
# 0                   63861.622807                                          9
# 1                   63864.638756                                 490.043898
# 2                   64026.517453                                          0
#
#   Compras netas en Mesa de Negociación (millones US$)
# 0                                                  9
# 1                                                109
# 2                                                  0

# %%
pd.to_numeric(series['Operaciones cambiarias BCRP (millones US$)'] ,errors = 'coerce')
# Out:
# 0         9.000000
# 1       490.043898
# 2         0.000000
# 3         0.000000
# 4         0.000000
#            ...
# 1078   -226.848729
# 1079      0.000000
# 1080      0.000000
# 1081     -1.670000
# 1082      0.000000
# Name: Operaciones cambiarias BCRP (millones US$), Length: 1083, dtype: float64

# %%
series['Reservas internacionales netas'] = pd.to_numeric(series['Reservas internacionales netas'] ,errors = 'coerce')

series['Operaciones cambiarias BCRP (millones US$)'] = pd.to_numeric(series['Operaciones cambiarias BCRP (millones US$)'] ,errors = 'coerce')

series['Compras netas en Mesa de Negociación (millones US$)'] = pd.to_numeric(series['Compras netas en Mesa de Negociación (millones US$)'] ,errors = 'coerce')
series.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1083 entries, 0 to 1082
# Data columns (total 8 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   fecha                                                1083 non-null   object
#  1   date                                                 1083 non-null   datetime64[ns]
#  2   var-tc                                               1082 non-null   float64
#  3   tc                                                   1083 non-null   float64
#  4   index                                                1083 non-null   float64
#  5   Reservas internacionales netas                       1082 non-null   float64
#  6   Operaciones cambiarias BCRP (millones US$)           1082 non-null   float64
#  7   Compras netas en Mesa de Negociación (millones US$)  1082 non-null   float64
# ...

# %%
sns.heatmap(series.iloc[:,[2,3,4,5,6,7 ]].corr(), annot=True)
# Out:
# <AxesSubplot:>
